# %%
pg.corr(
    x=summary_df["psi_threshold"].astype(float),
    y=summary_df["3_Pre_anxious"].astype(int),
)
# Out:
#            n         r         CI95%     p-val   BF10     power
# pearson  264  0.164754  [0.04, 0.28]  0.007306  2.759  0.767531

# %%
plt.figure(figsize=(3, 5))
sns.stripplot(data=hrd_df, y="psi_threshold", linewidth=1, alpha=0.6)
sns.boxplot(data=hrd_df, y="psi_threshold")
sns.despine()

# %%
plt.figure(figsize=(3, 5))
sns.stripplot(data=hrd_df, y="psi_slope", linewidth=1, alpha=0.6)
sns.boxplot(data=hrd_df, y="psi_slope")
sns.despine()
